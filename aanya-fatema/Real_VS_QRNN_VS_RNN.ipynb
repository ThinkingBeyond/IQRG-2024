# %%
import matplotlib.pyplot as plt

years = [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
rnn_values = [391.9207143, 393.7263636, 396.2558333, 398.37, 400.3858333, 403.7025, 406.2058333, 408.075, 411.2663636, 413.5466667, 415.9008333, 418.0475, 420.5175]
qrnn_values = [348.0731067, 348.0731067, 347.9869298, 347.9622052, 347.9828732, 347.9969144, 343.232335, 335.2439546, 336.4181959, 348.0860042, 347.6793927, 335.9170252, 333.428597]
real_values = [391.9747575, 394.1573604, 396.3695294, 398.6113229, 400.8827397, 403.1838, 405.5145152, 407.874833, 410.2647328, 412.6841785, 415.133076, 417.6113672, 420.1189295]

plt.plot(years, qrnn_values, marker='o', label='QRNN')
plt.plot(years, rnn_values, marker='o', label='RNN')
plt.plot(years, real_values, marker='o', label='Real')

plt.xlabel('Year')
plt.ylabel('Carbon Emissions [ppm]')
plt.title('Comparison of QRNN, RNN, and Real Values')

plt.legend()
plt.grid(True)
plt.show()
